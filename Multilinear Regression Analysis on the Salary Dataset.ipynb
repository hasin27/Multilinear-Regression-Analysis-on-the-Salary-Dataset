# %% [markdown]
# Step 1: Obtaining the Dataset
# The dataset can be downloaded from this link: https://www.kaggle.com/karthickveerakumar/salary-data-simple-linear-regression
#
# After downloading the dataset, we will import the necessary libraries and load the data into a pandas dataframe.

# %%
# Importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
data = pd.read_csv("E:\Masters Study\Python\Salary_Data.csv")

# %% [markdown]
# Step 2: Exploratory Data Analysis (EDA)
# After loading the data, we will perform EDA to better understand the dataset. We will start by checking the first few rows of the data and the column data types.

# %%
# Check the first few rows of the data
print(data.head())

# Check the column data types
print(data.dtypes)
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0
# YearsExperience    float64
# Salary             float64
# dtype: object

# %% [markdown]
# The output should show the first few rows of the data and the column data types. We can see that there are two columns in the dataset, "YearsExperience" and "Salary", both of which are numeric.
#
# Next, we will check for missing values in the dataset.

# %%
# Check for missing values
print(data.isnull().sum())
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %% [markdown]
# The output shows that there are no missing values in the dataset.
#
# We will now create some visualizations to better understand the relationship between the independent variables and the target variable.

# %%
# Create a scatter plot of the data
sns.scatterplot(x='YearsExperience', y='Salary', data=data)
plt.title('Salary vs Years of Experience')
plt.show()

# Create a box plot of the data
sns.boxplot(x='Salary', data=data)
plt.title('Distribution of Salary')
plt.show()

# %% [markdown]
# The scatter plot shows a positive linear relationship between years of experience and salary. The box plot shows that the salary distribution is skewed to the right, with a few high outliers.

# %% [markdown]
# Step 3: Data Preprocessing
# Now that we have a better understanding of the dataset, we will preprocess the data to prepare it for multilinear regression analysis.
#
# First, we will split the dataset into the independent variables (X) and the target variable (y). Next, we will split the data into training and testing sets.

# %%
# Split the dataset into X and y
X = data.drop('Salary', axis=1)
y = data['Salary']
# Split the data into training and testing sets
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %% [markdown]
# We will then scale the independent variables using standardization.

# %%
# Scale the independent variables using standardization
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# Step 4: Multilinear Regression Analysis
# We are now ready to perform multilinear regression analysis on the data. We will start by fitting a multilinear regression model on the training data.

# %%
# Fit a multilinear regression model on the training data
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# We will now use the trained model to make predictions on the test data and evaluate its performance.

# %%
# Make predictions on the test data
y_pred = regressor.predict(X_test)

# Evaluate the performance of the model on the test data
from sklearn.metrics import mean_squared_error, r2_score
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
print('Mean Squared Error:', mse)
print('R^2 Score:', r2)
# Out:
# Mean Squared Error: 12823412.298126562
# R^2 Score: 0.988169515729126

# %% [markdown]
# Finally, we can get our final model and use it to make predictions on new data. Here, We have predicted the salary for a new employee with 10 years of experience.

# %%
# Train the model on the entire dataset
X = sc.fit_transform(X)
regressor.fit(X, y)

# Make a prediction for a new employee with 10 years of experience
new_data = [[10]]
new_data = sc.transform(new_data)
new_salary = regressor.predict(new_data)
print('Predicted Salary:', new_salary)
# Out:
# Predicted Salary: [120291.82341322]
# E:\Anaconda\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %% [markdown]
# Here is the final code in one cell with all the requirements met.

# %%
#Final Code
# Importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# Load the dataset
data = pd.read_csv("E:\Masters Study\Python\Salary_Data.csv")

# Check the first few rows of the data
print(data.head())

# Check the column data types
print(data.dtypes)

# Check for missing values
print(data.isnull().sum())

# Create a scatter plot of the data
sns.scatterplot(x='YearsExperience', y='Salary', data=data)
plt.title('Salary vs Years of Experience')
plt.show()

# Create a box plot of the data
sns.boxplot(x='Salary', data=data)
plt.title('Distribution of Salary')
plt.show()

# Split the dataset into X and y
X = data.drop('Salary', axis=1)
y = data['Salary']

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# Scale the independent variables using standardization
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# Fit a multilinear regression model on the training data
regressor = LinearRegression()
regressor.fit(X_train, y_train)

# Make predictions on the test data
y_pred = regressor.predict(X_test)

# Evaluate the performance of the model on the test data
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
print('Mean Squared Error:', mse)
print('R^2 Score:', r2)

# Train the model on the entire dataset
X = sc.fit_transform(X)
regressor.fit(X, y)

# Make a prediction for a new employee with 10 years of experience
new_data = [[10]]
new_data = sc.transform(new_data)
new_salary = regressor.predict(new_data)
print('Predicted Salary:', new_salary)
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0
# YearsExperience    float64
# Salary             float64
# dtype: object
# YearsExperience    0
# Salary             0
# dtype: int64
# Mean Squared Error: 12823412.298126562
# R^2 Score: 0.988169515729126
# Predicted Salary: [120291.82341322]
# E:\Anaconda\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
